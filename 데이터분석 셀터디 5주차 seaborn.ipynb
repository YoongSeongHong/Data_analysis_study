# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
dowjones = sns.load_dataset("dowjones")
dowjones = pd.DataFrame({"Date": [1920, 1930, 1940, 1950, 1960, 1970],
                         "Price": [0, 200, 400, 600, 800, 1000]
                  })
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 sns.relplot(
#       2     data=fmri, kind="line",
#       3     x="timepoint", y="signal", errorbar=None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="event",
)

# %%
dots = sns.load_dataset("dots").query("align == 'dots'")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate",
    hue="coherence", style="choice",
)

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm", hue="species", multiple="stack")  # stack은 안겹치고 쌓는거

# %%
sns.displot(penguins, x="flipper_length_mm", hue="sex", multiple="dodge")

# %%
sns.displot(penguins, x="flipper_length_mm", kind="kde", bw_adjust=.25)  # 스무스한 꺾은선 그래프

# %%
diamonds = sns.load_dataset("diamonds")
sns.displot(diamonds, x="carat", kde=True)  # kde=True 추가하면 꺾은선그래프 같이

# %%
sns.displot(penguins, x="flipper_length_mm", kind="ecdf")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm")  # 색이 짙을수록 연관성이 크다

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", binwidth=(2, .5))

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", binwidth=(2, .5), cbar=True)  # 진할수록 많이 모여있다.

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde", thresh=.2, levels=4)

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde", levels=[.01, .05, .1, .8])

# %%
sns.displot(diamonds, x="price", y="clarity", log_scale=(True, False))

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.pairplot(penguins)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
tips = sns.load_dataset("tips")
sns.catplot(data=tips, x="day", y="total_bill")

# %%
sns.catplot(data=tips, x="day", y="total_bill", jitter=False)

# %%
sns.catplot(data=tips, x="day", y="total_bill", kind="swarm")

# %%
sns.catplot(data=tips, x="day", y="total_bill", hue="sex", kind="swarm")

# %%
sns.catplot(data=tips.query("size != 3"), x="size", y="total_bill")

# %%
sns.catplot(data=tips, x="smoker", y="tip", order=["No", "Yes"])

# %%
sns.catplot(data=tips, x="total_bill", y="day", hue="time", kind="swarm")

# %%
sns.catplot(data=tips, x="day", y="total_bill", kind="box")

# %%
sns.catplot(data=tips, x="day", y="total_bill", hue="smoker", kind="box")

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.catplot(
    data=tips, x="day", y="total_bill", hue="weekend",
    kind="box", dodge=False,  # 닷지 - 겹치지 않게하는거
)

# %%
diamonds = sns.load_dataset("diamonds")
sns.catplot(
    data=diamonds.sort_values("color"),
    x="color", y="price", kind="boxen",  # "boxen" - 부드러운 박스
)

# %%
sns.catplot(
    data=tips, x="total_bill", y="day", hue="sex", kind="violin",
)

# %%
sns.catplot(
    data=tips, x="total_bill", y="day", hue="sex",
    kind="violin", bw=.15, cut=0,
)

# %%
sns.catplot(
    data=tips, x="day", y="total_bill", hue="sex",
    kind="violin", split=True,
)

# %%
g = sns.catplot(data=tips, x="day", y="total_bill", kind="violin", inner=None)
sns.swarmplot(data=tips, x="day", y="total_bill", color="k", size=3, ax=g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="bar")

# %%
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="point")

# %%
sns.catplot(
    data=titanic, x="class", y="survived", hue="sex",
    palette={"male": "g", "female": "m"},
    markers=["^", "o"], linestyles=["-", "--"],
    kind="point"
)

# %%
sns.catplot(
    data=tips, x="day", y="total_bill", hue="smoker",
    kind="swarm", col="time", aspect=.7,
)

# %%
g = sns.catplot(
    data=titanic,
    x="fare", y="embark_town", row="class",
    kind="box", orient="h",
    sharex=False, margin_titles=True,
    height=1.5, aspect=4,
)
g.set(xlabel="Fare", ylabel="")
g.set_titles(row_template="{row_name} class")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter('${x:.0f}')

# %%
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)  # 위와 같은 그래프, lm이 parameter 쓸때 더 자유로움

# %%
sns.lmplot(x="size", y="tip", data=tips)

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           robust=True, ci=None, scatter_kws={"s": 80});  # 위 그래프에서 이상치때문에 휘어 올라가는걸 보정

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips, height=3);

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
