# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pokemon = pd.read_csv('pokemon.csv')

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
ord_pokemon = pokemon[pokemon["Legendary"]==False]

# %%
ord_pokemon.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
leg_pokemon = pokemon[pokemon["Legendary"]==True]

# %%
leg_pokemon.head(5)
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
sort_ord_poke = ord_pokemon.sort_values('Total',ascending=False)

# %%
sort_ord_poke.head(5)
# Out:
#        #                     Name  Type 1   Type 2  Total   HP  Attack  \
# 413  376  MetagrossMega Metagross   Steel  Psychic    700   80     145
# 494  445    GarchompMega Garchomp  Dragon   Ground    700  108     170
# 409  373  SalamenceMega Salamence  Dragon   Flying    700   95     145
# 268  248  TyranitarMega Tyranitar    Rock     Dark    700  100     164
# 313  289                  Slaking  Normal      NaN    670  150     160
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 413      150      105      110    110           3      False
# 494      115      120       95     92           4      False
# 409      130      120       90    120           3      False
# 268      150       95      120     71           2      False
# 313      100       95       65    100           3      False

# %%
ord_pokemon.sort_values('Total',ascending=True).head(5)
# Out:
#        #       Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 206  191    Sunkern   Grass     NaN    180  30      30       30       30
# 322  298    Azurill  Normal   Fairy    190  50      20       40       20
# 446  401  Kricketot     Bug     NaN    194  37      25       41       25
# 16    13     Weedle     Bug  Poison    195  40      35       30       20
# 13    10   Caterpie     Bug     NaN    195  45      30       35       20
#
#      Sp. Def  Speed  Generation  Legendary
# 206       30     30           2      False
# 322       40     20           3      False
# 446       41     25           4      False
# 16        20     50           1      False
# 13        20     45           1      False

# %%
leg_pokemon.sort_values('Total',ascending=False).head(5)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True
# 426      100      180      100    115           3       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True

# %%
leg_pokemon.sort_values('Total',ascending=True).head(5)
# Out:
#        #       Name   Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 156  144   Articuno      Ice    Flying    580  90      85      100       95
# 539  482      Azelf  Psychic       NaN    580  75     125       70      125
# 699  638   Cobalion    Steel  Fighting    580  91      90      129       90
# 700  639  Terrakion     Rock  Fighting    580  91     129       90       72
# 701  640   Virizion    Grass  Fighting    580  91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# 156      125     85           1       True
# 539       70    115           4       True
# 699       72    108           5       True
# 700       90    108           5       True
# 701      129    108           5       True

# %%
ord_pokemon["Type 1"].count()
# Out:
# 735

# %%
ord_pokemon["Type 1"]
# Out:
# 0       Grass
# 1       Grass
# 2       Grass
# 3       Grass
# 4        Fire
#         ...
# 787     Ghost
# 788       Ice
# 789       Ice
# 790    Flying
# 791    Flying
# Name: Type 1, Length: 735, dtype: object

# %%
ord_pokemon["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
ord_pokemon["Type 2"].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %% [markdown]
# 일반 포켓몬 수 735

# %%
ord_pokemon["Type 1"].value_counts()
# Out:
# Water       108
# Normal       96
# Bug          69
# Grass        67
# Fire         47
# Psychic      43
# Electric     40
# Rock         40
# Ghost        30
# Dark         29
# Poison       28
# Ground       28
# Fighting     27
# Steel        23
# Ice          22
# Dragon       20
# Fairy        16
# Flying        2
# Name: Type 1, dtype: int64

# %%
ord_pokemon["Type 2"].value_counts(dropna=False)
# Out:
# NaN         361
# Flying       84
# Poison       34
# Ground       34
# Psychic      28
# Grass        25
# Fighting     22
# Steel        21
# Fairy        21
# Dark         19
# Rock         14
# Dragon       14
# Ghost        13
# Water        13
# Ice          11
# Fire          9
# Electric      5
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
ord_pokemon.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean   353.315646  417.213605   67.182313   75.669388   71.559184   68.454422
# std    208.590419  106.760417   24.808849   30.490153   30.408194   29.091705
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    175.500000  324.000000   50.000000   54.500000   50.000000   45.000000
# 50%    346.000000  425.000000   65.000000   72.000000   66.000000   65.000000
# 75%    533.500000  498.000000   79.500000   95.000000   85.000000   85.000000
# max    715.000000  700.000000  255.000000  185.000000  230.000000  175.000000
#
#           Sp. Def       Speed  Generation
# count  735.000000  735.000000  735.000000
# mean    68.892517   65.455782    3.284354
# std     25.669310   27.843038    1.673471
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %%
sns.distplot(ord_pokemon["Attack"])

# %%
plt.scatter(ord_pokemon["Attack"], ord_pokemon["Defense"])

# %%
cond_Fire = ord_pokemon["Type 1"]=="Fire"
cond_Water = ord_pokemon["Type 1"]=="Water"

# %%
plt.scatter(ord_pokemon[cond_Fire]["Attack"], ord_pokemon[cond_Fire]["Defense"])

# %%
plt.scatter(ord_pokemon[cond_Water]["Attack"], ord_pokemon[cond_Water]["Defense"])

# %%
cond_Fighting = ord_pokemon["Type 1"]=="Fighting"
cond_Dragon = ord_pokemon["Type 1"]=="Dragon"
cond_Steel = ord_pokemon["Type 1"]=="Steel"
cond_Grass = ord_pokemon["Type 1"]=="Grass"
cond_Bug = ord_pokemon["Type 1"]=="Bug"

# %%
#plt.scatter(ord_pokemon[cond_Fire]["Attack"], ord_pokemon[cond_Fire]["Defense"], label="Fire")
#plt.scatter(ord_pokemon[cond_Water]["Attack"], ord_pokemon[cond_Water]["Defense"], label="Water")
#plt.scatter(ord_pokemon[cond_Fighting]["Attack"], ord_pokemon[cond_Fighting]["Defense"], label = "Fighting")
plt.scatter(ord_pokemon[cond_Dragon]["Attack"], ord_pokemon[cond_Dragon]["Defense"], label = "Dragon")
plt.scatter(ord_pokemon[cond_Steel]["Attack"], ord_pokemon[cond_Steel]["Defense"], label = "Steel")
#plt.scatter(ord_pokemon[cond_Grass]["Attack"], ord_pokemon[cond_Grass]["Defense"], label = "Grass")
#plt.scatter(ord_pokemon[cond_Bug]["Attack"], ord_pokemon[cond_Bug]["Defense"], label = "Bug")

plt.xlabel("Attack")
plt.ylabel("Defense")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ord_pokemon.groupby(["Attack","Defense"]).mean()
# Out:
#                     #  Total     HP  Sp. Atk  Sp. Def  Speed  Generation  \
# Attack Defense
# 5      5        276.5  335.0  175.0     25.0     85.0   40.0         2.5
# 10     10       242.0  540.0  255.0     75.0    135.0   55.0         2.0
#        55       129.0  200.0   20.0     15.0     20.0   80.0         1.0
#        230      213.0  505.0   20.0     10.0    230.0    5.0         2.0
# 15     20       349.0  200.0   20.0     10.0     55.0   80.0         3.0
# ...               ...    ...    ...      ...      ...    ...         ...
# 165    60       409.0  495.0   97.0     65.0     50.0   58.0         4.0
#        75       354.0  555.0   64.0     93.0     83.0   75.0         3.0
#        95       475.0  618.0   68.0     65.0    115.0  110.0         4.0
# 170    115      445.0  700.0  108.0    120.0     95.0   92.0         4.0
# 185    115      214.0  600.0   80.0     40.0    105.0   75.0         2.0
#
#                 Legendary
# Attack Defense
# 5      5            False
# ...

# %%
ord_pokemon.groupby(["Attack","Defense"])["HP"].mean()
# Out:
# Attack  Defense
# 5       5          175.0
# 10      10         255.0
#         55          20.0
#         230         20.0
# 15      20          20.0
#                    ...
# 165     60          97.0
#         75          64.0
#         95          68.0
# 170     115        108.0
# 185     115         80.0
# Name: HP, Length: 522, dtype: float64

# %%
ord_pokemon.groupby("Type 1")["Attack","Defense"].mean().sort_values(by="Attack", ascending = False)
# Out:
# C:\Users\ParkChunSoo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               Attack     Defense
# Type 1
# Dragon    103.400000   78.150000
# Fighting   96.777778   65.925926
# Steel      92.086957  126.652174
# Rock       89.925000   97.125000
# Ground     88.000000   79.821429
# Dark       86.862069   68.689655
# Fire       82.191489   64.531915
# Poison     74.678571   68.821429
# Ice        73.227273   68.818182
# Water      72.777778   71.990741
# Grass      72.119403   70.283582
# Normal     72.083333   58.697917
# Ghost      71.366667   79.266667
# Bug        70.971014   70.724638
# Electric   66.125000   65.425000
# Fairy      57.187500   63.875000
# Psychic    54.953488   61.000000
# Flying     50.000000   57.500000

# %%
plt.subplots(figsize = (30,20))
sns.violinplot(x = "Type 1", y = "Attack", data = ord_pokemon)

plt.ylim(0, 200)
plt.show()

# %%
plt.subplots(figsize = (30,20))
sns.violinplot(x = "Generation", y = "Total", data = ord_pokemon)

#plt.ylim(0, 200)
plt.show()

# %%
plt.subplots(figsize = (30,20))
sns.violinplot(x = "Attack", y = "Defense", data = ord_pokemon)

#plt.ylim(0, 200)
plt.show()

# %%
plt.subplots(figsize = (30,20))
sns.violinplot(x = "Type 1", y = "Speed", data = ord_pokemon)

#plt.ylim(0, 200)
plt.show()

# %%
plt.figure(figsize = (30,20))
sns.heatmap(ord_pokemon.corr(), cmap="YlGnBu", annot=True, annot_kws = {"size": 30})
sns.set(font_scale=2.0)

# %%
ord_pokemon.groupby("Generation")["Type 1","Total"].count().sort_values(by="Total", ascending = False)
# Out:
# C:\Users\ParkChunSoo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#             Type 1  Total
# Generation
# 1              160    160
# 5              150    150
# 3              142    142
# 4              108    108
# 2              101    101
# 6               74     74
