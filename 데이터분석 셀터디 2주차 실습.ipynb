# %%
import csv
f = open('population.csv')
data = csv.reader(f)
result = []
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
print(result)
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
import csv
import matplotlib.pyplot as plt

f = open('population.csv')
data = csv.reader(f)
result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: ')
for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',','')))
                         
plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.title(name+' 지역의 인구 구조')
plt.plot(result)

# %%
import csv
import matplotlib.pyplot as plt

f = open('population.csv')
data = csv.reader(f)
result = []
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
plt.bar(range(101), result)# 수직 바
plt.show()
plt.barh(range(101), result)  # 수평 바
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '군포1동' in row[0]:
        for i in row[3:104]:
            m.append(int(i))
        for i in row[106:]:
            f.append(int(i))

plt.barh(range(101), m)
plt.barh(range(101), f)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '군포1동' in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))

plt.rc('font', family='Malgun Gothic')
plt.title('군포1동 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))

plt.style.use('ggplot')
plt.figure(figsize=(10, 5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name+' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 군포1동

# %%
import csv
import matplotlib.pyplot as plt

f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))
        break  # 추가안하면 제주특별자치도 검색했을때 값이 너무 많이 나와서 에러뜨므로 가장 위 행만 검사 

plt.style.use('ggplot')
plt.figure(figsize=(10, 5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name+' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic') # 그래프에 한글 표시
size = [2441, 2312, 1031, 1233] # 데이터
label = ['A형', 'B형', 'AB형', 'O형'] # 레이블
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))  # explode는 돌출 효과, 여기서는 AB형을 강조함
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('population_mf.csv')
data = csv.reader(f)
size = []
name = input("찾고 싶은 지역의 이름을 알려주세요 : ")
for row in data:
    if name in row[0]:
        m = 0
        f = 0
        for i in range(101):
            m += int(row[i+3])
            f += int(row[i+106])
        break
size.append(m) # 남자 수
size.append(f) # 여자 수

plt.rc('font', family='Malgun Gothic')
color = ['crimson', 'darkcyan'] # 색상 설정
plt.axis('equal')
# startangle은 사분면 내에서 시작 각도 정해줌. 90도이니 12시 위치에서 시작
plt.pie(size, labels=['남', '여'], autopct='%.1f%%', colors=color, startangle=90)
plt.title(name+' 지역의 남녀 성별 비율')
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도

# %%
import csv
import matplotlib.pyplot as plt

f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
name = input('궁금한 동네를 입력해주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i]))
            f.append(int(row[i+103]))
        break
plt.plot(m, label='Male') # plot은 꺾은선 그래프
plt.plot(f, label='Female')
plt.legend()
plt.show()
# Out:
# 궁금한 동네를 입력해주세요: 제주특별자치도

# %%
import csv
import matplotlib.pyplot as plt

f = open('population_mf.csv')
data = csv.reader(f)
result = []
name = input('궁금한 동네를 입력해주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            result.append(int(row[i]) - int(row[i+103]))
        break
plt.bar(range(101), result)
plt.show()  # 60대 기준으로 그 밑은 남자가 더 많지만 그 위는 여자가 더 많음
# Out:
# 궁금한 동네를 입력해주세요: 제주특별자치도

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40], s=[100,200,250,300]) # s는 size 의미
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40], s=[30,60,90,120], c=['red', 'blue', 'green', 'gold']) #  c는 컬러 의미
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40], s=[30,60,90,120], c=['red', 'blue', 'green', 'gold']) #  c는 컬러 의미
plt.colorbar()
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29612\1475619079.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40], s=[30,60,90,120], c=range(4), cmap='brg') #  cmap은 컬러맵. 컬러바에 사용될 색 종류 지정
plt.colorbar()
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29612\1014309510.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
import matplotlib.pyplot as plt
import random
x = []
y = []
size = []
for i in range(100):
    x.append(random.randint(50, 100))
    y.append(random.randint(50, 100))
    size.append(random.randint(10, 100))
plt.scatter(x, y, s=size, c=size, cmap='jet', alpha=0.7) # alpha는 투명도
plt.colorbar()
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29612\3825695736.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
import csv
import matplotlib.pyplot as plt

f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
name = input('궁금한 동네를 입력해주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i]))
            f.append(int(row[i+103]))
        break
plt.scatter(m, f, c= range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)), 'g') # 추세선 추가
plt.show()
# Out:
# 궁금한 동네를 입력해주세요: 제주특별자치도
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29612\3194231642.py:16: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
# 제주도의 연령대별 성별 비율을 산점도로 표현하기
import csv
import matplotlib.pyplot as plt
import math
f = open('population_mf.csv')
data = csv.reader(f)
m = []
f = []
size = []
name = input('궁금한 동네를 입력해주세요: ')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i]))
            f.append(int(row[i+103]))
            size.append(math.sqrt(int(row[i]) + int(row[i+103])))
        break
plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(10, 5))
plt.title(name+ ' 지역의 성별 인구 그래프')
plt.scatter(m, f, s=size, c=range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)), range(max(m)), 'g')
plt.xlabel('남성 인구수')
plt.ylabel('여성 인구수')
plt.show()
# Out:
# 궁금한 동네를 입력해주세요: 제주
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29612\2052286715.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
